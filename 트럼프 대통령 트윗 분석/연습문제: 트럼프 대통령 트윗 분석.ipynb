# %% [markdown]
# # 1-1. 캐글 데이터 찾기
# ### 문제
#
# 1. 캐글([www.kaggle.com)](http://www.kaggle.xn--com%29-g040a/)에서 회원가입을 하세요. 구글 계정이 있으면 쉽게 가입할 수 있어요.
# 2. “iris dataset”를 검색하고, 검색결과에서 “**Iris Dataset**”을 찾아서 [Data] 탭에서  “iris.data.csv” 파일을 다운로드하세요. (링크: [https://www.kaggle.com/datasets/vikrishnan/iris-dataset](https://www.kaggle.com/datasets/vikrishnan/iris-dataset))
# 3. 다운로드한 압축파일을 풀고 판다스 read_csv 함수를 사용하여 CSV 파일을 읽어주세요. (header=None) 변환된 데이터프레임을 변수 df에 저장하고, 첫 5행의 데이터를 출력하세요.
# 4. 데이터프레임의 열(컬럼) 이름을 ['Sepal_length','Sepal_width','Petal_length','Petal_width','Species'] 으로 변경하세요. 그리고, 첫 5행의 데이터를 출력하세요.

# %%
import pandas as pd

# %%
df = pd.read_csv('./iris.data.csv', header = None)
# 컬럼명 변경
df.columns = ['Sepal_length','Sepal_width','Petal_length','Petal_width','Species'] 
df.head(5)
# Out:
#    Sepal_length  Sepal_width  Petal_length  Petal_width      Species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# # 1-2.데이터프레임에서 필요한 데이터 찾기
#
# 1. df 데이터프레임에서 ‘Species’ 열을 선택합니다. 그리고, 첫 번째 원소를 추출하여 화면에 출력하세요.
# 2. df 데이터프레임에서 ‘Species’ 열을 제외하고, 나머지 'Sepal_length'열부터 ‘Petal_width'열까지 선택하여 화면에 출력하세요.
# 3. df 데이터프레임에서 ‘Species’ 열을 제외하고, 나머지 'Sepal_length'열부터 ‘Petal_width'열까지 선택하여 화면에 출력하세요. (2번 문제와 다른 방식(코드/문법)를 사용해서 문제를 풀어주세요.)
# 4. df 데이터프레임에서 Sepal_length'열과 ‘Species'열을 선택하고 화면에 출력하세요.
# 5. 4번에서 선택한 데이터프레임에서 10번째부터 13번째 행 인덱스에 해당하는 데이터를 추출하고 화면에 출력하세요.

# %% [markdown]
# 1. df 데이터프레임에서 ‘Species’ 열을 선택합니다. 그리고, 첫 번째 원소를 추출하여 화면에 출력하세요.

# %%
df['Species'][0]
# Out:
# 'Iris-setosa'

# %% [markdown]
# 2. df 데이터프레임에서 ‘Species’ 열을 제외하고, 나머지 'Sepal_length'열부터 ‘Petal_width'열까지 선택하여 화면에 출력하세요.

# %%
df.loc[:,'Sepal_length':'Petal_width']
# Out:
#      Sepal_length  Sepal_width  Petal_length  Petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %% [markdown]
# 3. df 데이터프레임에서 ‘Species’ 열을 제외하고, 나머지 'Sepal_length'열부터 ‘Petal_width'열까지 선택하여 화면에 출력하세요. (2번 문제와 다른 방식(코드/문법)를 사용해서 문제를 풀어주세요.)

# %%
df[['Sepal_length','Sepal_width','Petal_length','Petal_width']]
# Out:
#      Sepal_length  Sepal_width  Petal_length  Petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %% [markdown]
# 4. df 데이터프레임에서 Sepal_length'열과 ‘Species'열을 선택하고 화면에 출력하세요.

# %%
speci_df = df[['Sepal_length','Species']]
speci_df
# Out:
#      Sepal_length         Species
# 0             5.1     Iris-setosa
# 1             4.9     Iris-setosa
# 2             4.7     Iris-setosa
# 3             4.6     Iris-setosa
# 4             5.0     Iris-setosa
# ..            ...             ...
# 145           6.7  Iris-virginica
# 146           6.3  Iris-virginica
# 147           6.5  Iris-virginica
# 148           6.2  Iris-virginica
# 149           5.9  Iris-virginica
#
# [150 rows x 2 columns]

# %% [markdown]
# 5. 4번에서 선택한 데이터프레임에서 10번째부터 13번째 행 인덱스에 해당하는 데이터를 추출하고 화면에 출력하세요.

# %%
speci_df.iloc[10:14]
# Out:
#     Sepal_length      Species
# 10           5.4  Iris-setosa
# 11           4.8  Iris-setosa
# 12           4.8  Iris-setosa
# 13           4.3  Iris-setosa

# %% [markdown]
# # 3. 문자열 데이터를 찾아서 바꾸기
#
# ## 문제
#
# ---
#
# 1. ‘Species’ 열의 첫 번째 데이터는 ‘Iris-setosa’ 라는 문자열입니다. ‘-’ 문자를 기준으로 ‘Iris’와 ‘setosa’로 분할하고 2번째 원소를 선택하세요.
# 2. ‘Species’ 열의 첫 번째 데이터는 ‘Iris-setosa’ 라는 문자열입니다.  ‘Iris-’에 해당하는 문자열을 제거하고 ‘setosa’와 같이 변환하세요.
# 3. ‘Species’ 열의 모든 데이터를 대상으로, ‘Iris-’에 해당하는 문자열을 제거하고 그 결과를  ‘Species_1’ 열을 추가하여 저장하세요. 단, 파이썬 replace 함수를 사용하세요.
# 4. ‘Species’ 열의 모든 데이터를 대상으로, ‘Iris-’에 해당하는 문자열을 제거하고 그 결과를  ‘Species_2’ 열을 추가하여 저장하세요. 단, 파이썬 split 함수를 사용하세요.

# %% [markdown]
# 1. ‘Species’ 열의 첫 번째 데이터는 ‘Iris-setosa’ 라는 문자열입니다. ‘-’ 문자를 기준으로 ‘Iris’와 ‘setosa’로 분할하고 2번째 원소를 선택하세요.

# %%
str = df['Species'][0]

Species_1_data = str.split('-')
Species_1_data[1]
# Out:
# 'setosa'

# %% [markdown]
# 2. ‘Species’ 열의 첫 번째 데이터는 ‘Iris-setosa’ 라는 문자열입니다.  ‘Iris-’에 해당하는 문자열을 제거하고 ‘setosa’와 같이 변환하세요.

# %%
df['Species'][0] = Species_1_data[1]
df
# Out:
# /var/folders/5v/qstscrlx4tsddzht4m9xgdcm0000gn/T/ipykernel_14249/3328142142.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Species'][0] = Species_1_data[1]
#      Sepal_length  Sepal_width  Petal_length  Petal_width         Species
# 0             5.1          3.5           1.4          0.2          setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# ...

# %% [markdown]
# 3. ‘Species’ 열의 모든 데이터를 대상으로, ‘Iris-’에 해당하는 문자열을 제거하고 그 결과를  ‘Species_1’ 열을 추가하여 저장하세요. 단, 파이썬 replace 함수를 사용하세요.

# %%
df['Species_1'] = df['Species']

df['Speiceis_1'] = df['Species'].replace({'Iris-setosa' : 'setosa', 'Iris-virginica': 'virginica' })
df
# Out:
#      Sepal_length  Sepal_width  Petal_length  Petal_width         Species  \
# 0             5.1          3.5           1.4          0.2          setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
#           Species_1 Speiceis_1
# 0            setosa     setosa
# ...

# %% [markdown]
# 4. ‘Species’ 열의 모든 데이터를 대상으로, ‘Iris-’에 해당하는 문자열을 제거하고 그 결과를  ‘Species_2’ 열을 추가하여 저장하세요. 단, 파이썬 split 함수를 사용하세요.

# %%
str = df['Species']
Species_1 = df['Species'] 
df['Species_2'] = df['Species']
for i in range(1,150):
    str_li = df['Species'][i].split('-')
    df['Species_2'][i] = str_li[1]
    


df
# Out:
# /var/folders/5v/qstscrlx4tsddzht4m9xgdcm0000gn/T/ipykernel_14249/2732983649.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Species_2'][i] = str_li[1]
#      Sepal_length  Sepal_width  Petal_length  Petal_width         Species  \
# 0             5.1          3.5           1.4          0.2          setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# ...

# %% [markdown]
# # 1-4. 워드 클라우드 만들기
#
# 1. df 데이터프레임의 ‘Species_2’ 컬럼에 들어 있는 품종 데이터의 도수를 계산하세요. 이때 파이썬 for 반복문를 사용하고 딕셔너리에 그 결과를 정리하세요.
# 2. 파이썬 collections 모듈의 Counter 함수를 사용하여 ‘Species_2’ 컬럼에 들어 있는 품종 데이터의 도수를 계산하세요.
# 3. 판다스 시리즈 객체의 value_counts 함수를 적용하여 ‘Species_2’ 컬럼에 들어 있는 품종 데이터의 도수를 계산하세요.
# 4. 위 3번에서 계산한 도수를 막대그래프로 표현하세요. (힌트: 판다스 시리즈에 plot 메소드 함수를 적용하세요)
# 5. wordcloud 라이브러리를 설치하세요. (pip install wordcloud) 그리고, 아래 코드를 이용하여 워드클라우드를 화면에 출력하세요. (힌트: string_data 변수에는 문자열을 하나로 결합하여 입력하세요. )
# 6. 아래 코드를 이용하여 워드클라우드를 화면에 출력하세요. (힌트: dict_data 변수에는 1번 또는 2번 문제에서 정리한 딕셔너리를 입력하세요. )

# %% [markdown]
# 1. df 데이터프레임의 ‘Species_2’ 컬럼에 들어 있는 품종 데이터의 도수를 계산하세요. 이때 파이썬 for 반복문를 사용하고 딕셔너리에 그 결과를 정리하세요.

# %%
Spe_2_dict = dict()
for i in range(len(df['Species_2'])):
    
    Spe_2_dict[df['Species_2'][i]] = 0
    
    
 



i = 0 
j = 0
k = 0
for label in df['Species_2']:
    if label == 'setosa':
        i += 1
        
    elif label == 'versicolor':
        j += 1
    elif label == 'virginica':
        k += 1
Spe_2_dict['setosa'] = i
Spe_2_dict['versicolor'] = j
Spe_2_dict['virginica'] = k

print(Spe_2_dict)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [59], line 1
# ----> 1 Spe_2_dict = dict()
#       2 for i in range(len(df['Species_2'])):
#       4     Spe_2_dict[df['Species_2'][i]] = 0
#
# TypeError: 'dict' object is not callable

# %% [markdown]
# 2. 파이썬 collections 모듈의 Counter 함수를 사용하여 ‘Species_2’ 컬럼에 들어 있는 품종 데이터의 도수를 계산하세요.

# %%
from collections import Counter

Counter(df['Species_2'])
# Out:
# Counter({'setosa': 50, 'versicolor': 50, 'virginica': 50})

# %% [markdown]
# 3. 판다스 시리즈 객체의 value_counts 함수를 적용하여 ‘Species_2’ 컬럼에 들어 있는 품종 데이터의 도수를 계산하세요.

# %%
b= df['Species_2'].value_counts()

# %% [markdown]
# 4. 위 3번에서 계산한 도수를 막대그래프로 표현하세요. (힌트: 판다스 시리즈에 plot 메소드 함수를 적용하세요)

# %%
b.plot(kind= 'bar')
# Out:
# <AxesSubplot: >

# %% [markdown]
# 5. wordcloud 라이브러리를 설치하세요. (pip install wordcloud) 그리고, 아래 코드를 이용하여 워드클라우드를 화면에 출력하세요. (힌트: string_data 변수에는 문자열을 하나로 결합하여 입력하세요. )

# %%
# %pip install wordcloud
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# WARNING: You are using pip version 21.2.4; however, version 22.3.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
# 문자열 결합
string_data = ' '.join(df['Species_2'].values)
print("결합된 문자열: ", string_data)


# WordCloud 생성
from wordcloud import WordCloud, STOPWORDS 
wordcloud = WordCloud(width = 400, height = 400, 
                     ).generate(string_data) 
  
# WordCloud 출력                    
plt.figure(figsize = (4, 4), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout() 
plt.show()
# Out:
# 결합된 문자열:  setosa setosa setosa setosa setosa setosa setosa setosa setosa setosa setosa setosa setosa setosa setosa setosa setosa setosa setosa setosa setosa setosa setosa setosa setosa setosa setosa setosa setosa setosa setosa setosa setosa setosa setosa setosa setosa setosa setosa setosa setosa setosa setosa setosa setosa setosa setosa setosa setosa setosa versicolor versicolor versicolor versicolor versicolor versicolor versicolor versicolor versicolor versicolor versicolor versicolor versicolor versicolor versicolor versicolor versicolor versicolor versicolor versicolor versicolor versicolor versicolor versicolor versicolor versicolor versicolor versicolor versicolor versicolor versicolor versicolor versicolor versicolor versicolor versicolor versicolor versicolor versicolor versicolor versicolor versicolor versicolor versicolor versicolor versicolor versicolor versicolor versicolor versicolor virginica virginica virginica virginica virginica virginica virginica virginica virginic
# ...

# %% [markdown]
# 6. 아래 코드를 이용하여 워드클라우드를 화면에 출력하세요. (힌트: dict_data 변수에는 1번 또는 2번 문제에서 정리한 딕셔너리를 입력하세요. )

# %%
print(Spe_2_dict)
dict_data =Spe_2_dict
# WordCloud 생성
from wordcloud import WordCloud, STOPWORDS 
wordcloud = WordCloud(width = 400, height = 400, 
                      background_color ='black', 
                      stopwords = set(STOPWORDS), 
                      max_words=3,
                      max_font_size = 100,
                     ).generate_from_frequencies(dict_data) 
  
# WordCloud 출력                    
plt.figure(figsize = (4, 4), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout() 
plt.show()
# Out:
# {'setosa': 50, 'versicolor': 50, 'virginica': 50}
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [24], line 13
#       5 wordcloud = WordCloud(width = 400, height = 400,
#       6                       background_color ='black',
#       7                       stopwords = set(STOPWORDS),
#       8                       max_words=3,
#       9                       max_font_size = 100,
#      10                      ).generate_from_frequencies(dict_data)
#      12 # WordCloud 출력
# ---> 13 plt.figure(figsize = (4, 4), facecolor = None)
#      14 plt.imshow(wordcloud)
#      15 plt.axis("off")
#
# NameError: name 'plt' is not defined
